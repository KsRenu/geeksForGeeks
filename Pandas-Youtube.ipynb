# %%
# 1) Intro
#  * what is pandas? 
#  * what using excel/plain python notb good. 
#  * Show how pandas increase productivity
 
# 2) Dataframe basics
#  * What is dataframe?
#  * Dealing with rows and columns
#  * Operations: mean, max, std, describe
#  * Conditional selection
#  * set_index
 
# 3) Different ways of creating dataframe
#  * dictionary, tuples list, list of dictionaries, csv, excel
 
# -) reading/writing to excel/csv: http://pbpython.com/excel-pandas-comp.html

# -) Handling Missing Data 
#  * dropna
#  * fillna
#  * isnull
#  * df.reindex
 
# -) Excel Like Operations
#  * sort
#  * filter
#  * remove/rename columns
#  * .duplicated 
#  * 

# -) Selection of data 
#  * df['A'] or df.A
#  * df[0:3]
#  * df['20130102':'20130104']
#  * df.loc['Rain'] or df.at['Rain']
#  * df.iloc[3]
#  * df.iat[1,1]
#  * df[df.A > 0]
 

 
# -) Merge/Concat/Join
# -) Grouping
# -) Reshaping/Stack/Unstack
# -) Pivot Table
# -) Time Series and Categoricals
# -) Plotting (Bokeh?)

# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\1b.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %% [markdown]
# # <font color="purple"><h3 align="center">DataFrame Basics Tutorial</h3></font>

# %% [markdown]
# ## **Dataframe is most commonly used object in pandas. It is a table like datastructure containing rows and columns similar to excel spreadsheet**

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\2b.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape # rows, columns = df.shape
# Out:
# (6, 4)

# %%
df.head() # df.head(3)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.tail() # df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[1:3]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color='blue'>Columns</font>

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df['day'] # or df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df['day'])
# Out:
# pandas.core.series.Series

# %%
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %% [markdown]
# ## <font color='blue'>Operations On DataFrame</font>

# %%
df['temperature'].max()
# Out:
# 35

# %%
df[df['temperature']>32]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df['day'][df['temperature'] == df['temperature'].max()] # Kinda doing SQL in pandas
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df['event'].max() # But mean() won't work since data type is string
# Out:
# 'Sunny'

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %% [markdown]
# **Google pandas series operations to find out list of all operations**
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html

# %% [markdown]
# ## <font color='blue'>set_index</font>

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# Index(['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'], dtype='object', name='day')

# %%
df.loc['1/2/2017']
# Out:
# temperature       35
# windspeed          7
# event          Sunny
# Name: 1/2/2017, dtype: object

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.set_index('event',inplace=True) # this is kind of building a hash map using event as a key
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %% [markdown]
# # <font color="purple"><h3 align="center">Different Ways Of Creating Dataframe</h3></font>

# %% [markdown]
# ## <font color="green">Using csv</h3></font>

# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\3b.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using excel</h3></font>

# %%
df=pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\3c.xlsx","Sheet1")
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %% [markdown]
# ## <font color="green">Using dictionary</h3></font>

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using tuples list</h3></font>

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using list of dictionaries</h3></font>

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="purple"><h4 align="center">Read/Write CSV and Excel Files in Pandas</font>

# %% [markdown]
# ### <font color="blue">Read CSV</color>

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4e.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4e.csv", skiprows=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4e.csv", header=1) # skiprows and header are kind of same
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4e.csv", header=None, names = ["ticker","eps","revenue","people"])
df
# Out:
#                 ticker      eps revenue         people
# tickers            eps  revenue   price         people
# GOOGL            27.82       87     845     larry page
# WMT               4.61      484      65           n.a.
# MSFT                -1       85      64     bill gates
# RIL      not available       50    1023  mukesh ambani
# TATA               5.6       -1    n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4e.csv",  nrows=2)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4e.csv", na_values=["n.a.", "not available"])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4e.csv",  na_values={
        'eps': ['not available'],
        'revenue': [-1],
        'people': ['not available','n.a.']
    })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %% [markdown]
# # Write csv

# %%
df.to_csv("new.csv")
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df2=df.index
df2
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.to_csv("new.csv", index=False)
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("new.csv",header=False)

# %%
df.to_csv("new.csv", columns=["tickers","price"], index=False)

# %% [markdown]
# ### <font color="blue">Read Excel</color>

# %%
# df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4c.xlsx","stocks")
# df

# %%
# def convert_people_cell(cell):
#     if cell=="n.a.":
#         return 'Sam Walton'
#     return cell

# def convert_price_cell(cell):
#     if cell=="n.a.":
#         return 50
#     return cell
    
# df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4c.xlsx","stocks", converters= {
#         'people': convert_people_cell,
#         'price': convert_price_cell
#     })
# df

# %% [markdown]
# ### <font color="blue">Write to Excel</color>

# %%
# df.to_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\4c.xlsx", sheet_name="stocks", index=False, startrow=2, startcol=1)

# %% [markdown]
# **Write two dataframes to two separate sheets in excel**

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")

# %%
len(df)
# Out:
# 5

# %%
df[df_weather].nunique()
# Out:
# tickers    0
# eps        0
# revenue    0
# price      0
# people     0
# dtype: int64

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Handling Missing Data - fillna, interpolate, dropna</font>

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\5d.csv",parse_dates=['day'])
type(df.day[0])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ## <font color="blue">fillna</font>

# %% [markdown]
# <font color="purple">**Fill all NaN with one specific value**</font>

# %%
new_df = df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# <font color="purple">**Fill na using column names and dict**</font>

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': 0,
        'event': 'No Event'
    })
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  No Event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  No Event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %% [markdown]
# <font color="purple">**Use method to determine how to fill na values**</font>

# %%
new_df = df.fillna(method="ffill")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="bfill")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# <font color="purple">**Use of axis**</font>

# %%
new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04         9.0       9.0   Sunny
# 2017-01-05        28.0      Snow    Snow
# 2017-01-06         7.0       7.0     NaN
# 2017-01-07        32.0      Rain    Rain
# 2017-01-08       Sunny     Sunny   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10        34.0       8.0  Cloudy
# 2017-01-11        40.0      12.0   Sunny

# %% [markdown]
# <font color="purple">**limit parameter**</font>

# %%
new_df = df.fillna(method="ffill",limit=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### <font color="blue">interpolate</font>

# %%
new_df = df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df = df.interpolate(method="time") 
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %% [markdown]
# **Notice that in above temperature on 2017-01-04 is 29 instead of 30 (in plain linear interpolate)**
# **There are many other methods for interpolation such as quadratic, piecewise_polynomial, cubic etc.
# Just google "dataframe interpolate" to see complete documentation**

# %% [markdown]
# ### <font color="blue">dropna</font>

# %%
new_df=df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(how="all")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna(thresh=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### <font color="blue">Inserting Missing Dates</font>

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\5d.csv", parse_dates=["day"])
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# %matplotlib inline
df.temperature.plot.bar()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
new_df = df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Handling Missing Data - replace method</font>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\6b.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# **Replacing single value**

# %%
new_df = df.replace(-99999, value=np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %% [markdown]
# **Replacing list with single value**

# %%
new_df = df.replace(to_replace=[-99999,-88888], value=0)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017            0          7  Sunny
# 2  1/3/2017           28          0   Snow
# 3  1/4/2017            0          7      0
# 4  1/5/2017           32          0   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# **Replacing per column**

# %%
new_df = df.replace({
        'temperature': -99999,
        'windspeed': -99999,
        'event': '0'
    }, np.nan)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %% [markdown]
# **Replacing by using mapping**

# %%
new_df = df.replace({
        -99999: np.nan,
        'no event': 'Sunny',
    })
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %% [markdown]
# **Regex**

# %%
# when windspeed is 6 mph, 7 mph etc. & temperature is 32 F, 28 F etc.
new_df = df.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'},'', regex=True) 
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %% [markdown]
# **Replacing list with another list**

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Pandas Group By</font>

# %% [markdown]
# **In this tutorial we are going to look at weather data from various cities and see how group by can be used to run some analytics.**

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\7d.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %% [markdown]
# ### For this dataset, get following answers,
# #### 1. What was the maximum temperature in each of these 3 cities?
# #### 2. What was the average windspeed in each of these 3 cities?

# %%
g = df.groupby("city")
g

# %% [markdown]
# **DataFrameGroupBy object looks something like below,**

# %% [markdown]
# <img src="group_by_cities.png">

# %%
for city, data in g:
    print("city:",city)
    print("\n")
    print("data:",data)
# Out:
# city: mumbai
#
#
# data:         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# city: new york
#
#
# data:         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# city: paris
#
#
# data:          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %% [markdown]
# **This is similar to SQL,**
#
# **SELECT * from weather_data GROUP BY city**

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %% [markdown]
# **This method of splitting your dataset in smaller groups and then applying an operation
# (such as min or max) to get aggregate result is called Split-Apply-Combine. It is illustrated in a diagram below**

# %% [markdown]
# <img src="split_apply_combine.png">

# %%
g.min()
# Out:
#                day  temperature  windspeed   event
# city
# mumbai    1/1/2017           85          5     Fog
# new york  1/1/2017           28          6    Rain
# paris     1/1/2017           42          8  Cloudy

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
g.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
g.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# <h4>Group data using custom function: Let's say you want to group your data using custom function. Here the requirement is to create three groups<h4>
# <ol>
#     <li>Days when temperature was between 80 and 90</li>
#     <li>Days when it was between 50 and 60</li>
#     <li>Days when it was anything else</li>
# </ol>

# %% [markdown]
# For this you need to write custom grouping function and pass that to groupby

# %%
def grouper(df, idx, col):
    if 80 <= df[col].loc[idx] <= 90:
        return '80-90'
    elif 50 <= df[col].loc[idx] <= 60:
        return '50-60'
    else:
        return 'others'

# %%
g = df.groupby(lambda x: grouper(df, x, 'temperature'))
g

# %%
for key, d in g:
    print("Group by Key: {}\n".format(key))
    print(d)
# Out:
# Group by Key: 50-60
#
#          day   city  temperature  windspeed   event
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# Group by Key: 80-90
#
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# Group by Key: others
#
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 11  1/4/2017     paris           42         10  Cloudy

# %% [markdown]
# # <font color="purple"><h3 align="center">Pandas Concatenate</h3></font>

# %% [markdown]
# ## <font color='blue'>Basic Concatenation</font>

# %%
import pandas as pd

india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# ## <font color='blue'>Ignore Index</font>

# %%
df = pd.concat([india_weather, us_weather], ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %% [markdown]
# ## <font color='blue'>Concatenation And Keys</font>

# %%
df = pd.concat([india_weather, us_weather], keys=["india", "us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc["us"]
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df.loc["india"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %% [markdown]
# ## <font color='blue'>Concatenation Using Index</font>

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %% [markdown]
# ## <font color='blue'>Concatenate dataframe with series</font>

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temperature_df,s],axis=1)
df
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain

# %% [markdown]
# # <font color="purple"><h3 align="center">Pandas Merge Tutorial</h3></font>

# %% [markdown]
# ## <font color='blue'>Basic Merge Using a Dataframe Column</font>

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df3 = pd.merge(df1, df2, on="city")
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# ## <font color='blue'>Type Of DataBase Joins</font>

# %% [markdown]
# <img src="db_joins.jpg" height="800", width="800">

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3=pd.merge(df1,df2,on="city",how="inner")
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df3=pd.merge(df1,df2,on="city",how="outer")
df3
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %%
df3=pd.merge(df1,df2,on="city",how="left")
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right")
df3
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %% [markdown]
# ## <font color='blue'>indicator flag</font>

# %%
df3=pd.merge(df1,df2,on="city",how="outer",indicator=True)
df3
# Out:
#         city  temperature  humidity      _merge
# 0   new york         21.0      68.0        both
# 1    chicago         14.0      65.0        both
# 2    orlando         35.0       NaN   left_only
# 3  baltimore         38.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %%
df3=pd.merge(df1,df2,on="city",how="outer",indicator=False)
df3
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %% [markdown]
# ## <font color='blue'>suffixes</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df3= pd.merge(df1,df2,on="city",how="outer", suffixes=('_first','_second'))
df3
# Out:
#         city  temperature_first  humidity_first  temperature_second  \
# 0   new york               21.0            65.0                14.0
# 1    chicago               14.0            68.0                21.0
# 2    orlando               35.0            71.0                 NaN
# 3  baltimore               38.0            75.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity_second
# 0             68.0
# 1             65.0
# 2              NaN
# 3              NaN
# 4             71.0

# %% [markdown]
# ## <font color='blue'>join</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1.set_index('city',inplace=True)
df1
# Out:
#           temperature
# city
# new york           21
# chicago            14
# orlando            35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2.set_index('city',inplace=True)
df2
# Out:
#           humidity
# city
# chicago         65
# new york        68
# orlando         75

# %%
df1.join(df2,lsuffix='_l', rsuffix='_r')
# Out:
#           temperature  humidity
# city
# new york           21        68
# chicago            14        65
# orlando            35        75

# %% [markdown]
# <h1 style="color:blue">Pivot basics</h1>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\10b.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='city',columns='date')
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
df.pivot(index='city',columns='date',values="humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index='humidity',columns='city')
# Out:
#               date                     temperature
# city       beijing    mumbai  new york     beijing mumbai new york
# humidity
# 26        5/1/2017       NaN       NaN        80.0    NaN      NaN
# 30        5/2/2017       NaN       NaN        77.0    NaN      NaN
# 35        5/3/2017       NaN       NaN        79.0    NaN      NaN
# 56             NaN       NaN  5/1/2017         NaN    NaN     65.0
# 58             NaN       NaN  5/2/2017         NaN    NaN     66.0
# 60             NaN       NaN  5/3/2017         NaN    NaN     68.0
# 80             NaN  5/1/2017       NaN         NaN   75.0      NaN
# 83             NaN  5/2/2017       NaN         NaN   78.0      NaN
# 85             NaN  5/3/2017       NaN         NaN   82.0      NaN

# %% [markdown]
# <h1 style="color:blue">Pivot Table</h1>

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\10c.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index="city",columns="date")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %% [markdown]
# <h2 style="color:brown">Margins</h2>

# %%
df.pivot_table(index="city",columns="date", margins=False,aggfunc=np.sum)
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
# Out:
#          humidity               temperature
# date     5/1/2017 5/2/2017  All    5/1/2017 5/2/2017  All
# city
# mumbai        163      111  274         153      162  315
# new york      110      122  232         126      142  268
# All           273      233  506         279      304  583

# %% [markdown]
# <h2 style="color:brown">Grouper</h2>

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\10d.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# # <font color="purple"><h3 align="center">Reshape pandas dataframe using melt</h3></font>

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\11b.csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
melted = pd.melt(df, id_vars=["day"], var_name='city', value_name='temperature')
melted
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %%
df1=pd.melt(df,id_vars=["day"])

# %% [markdown]
# <h1 style="color:blue">Reshape dataframe using stack/unstack</h1>

# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\12b.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df.stack()
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# 3 Company       NaN                            NaN         2017-06-08
#   Facebook    155.0                          36.11                NaT
#   Google     1000.0                          31.20                NaT
#   Microsoft    61.0                          30.11                NaT
# 4 Company       NaN                            NaN         2017-06-09
#   Facebook    156.0                          37.07                NaT
#   Google     1012.0                          30.00                NaT
#   Microsoft    66.0                          31.00                NaT

# %%
df.stack(level=0)
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# 4 Price                                NaT    156.00  1012.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.07    30.0      31.00
#   Unnamed: 0_level_0            2017-06-09       NaN     NaN        NaN

# %%
df_stacked=df.stack()
df_stacked
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# 3 Company       NaN                            NaN         2017-06-08
#   Facebook    155.0                          36.11                NaT
#   Google     1000.0                          31.20                NaT
#   Microsoft    61.0                          30.11                NaT
# 4 Company       NaN                            NaN         2017-06-09
#   Facebook    156.0                          37.07                NaT
#   Google     1012.0                          30.00                NaT
#   Microsoft    66.0                          31.00                NaT

# %%
df_stacked.unstack()
# Out:
#     Price                            Price to earnings ratio (P/E)           \
#   Company Facebook  Google Microsoft                       Company Facebook
# 0     NaN    155.0   955.0      66.0                           NaN    37.10
# 1     NaN    150.0   987.0      69.0                           NaN    36.98
# 2     NaN    153.0   963.0      62.0                           NaN    36.78
# 3     NaN    155.0  1000.0      61.0                           NaN    36.11
# 4     NaN    156.0  1012.0      66.0                           NaN    37.07
#
#                    Unnamed: 0_level_0
#   Google Microsoft            Company Facebook Google Microsoft
# 0   32.0     30.31         2017-06-05      NaT    NaT       NaT
# 1   31.3     30.56         2017-06-06      NaT    NaT       NaT
# 2   31.7     30.46         2017-06-07      NaT    NaT       NaT
# 3   31.2     30.11         2017-06-08      NaT    NaT       NaT
# 4   30.0     31.00         2017-06-09      NaT    NaT       NaT

# %% [markdown]
# <h1 style="color:blue">3 levels of column headers</h1>

# %%
df2 = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\12c.xlsx",header=[0,1,2])
df2
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# 4                         37.07   30.0     31.00              8.1     31
#
#
#             Net Profit
#   Microsoft   Facebook Google Microsoft
# 0     18.70       0.80   5.43      4.56
# 1     21.30       0.97   5.89      5.10
# 2     21.45       1.20   6.10      5.43
# 3     21.88       1.67   6.50      5.89
# 4     22.34       2.03   6.40      6.09

# %%
df2.stack()
# Out:
#             Income Statement           Price Ratios  \
#                   Net Profit Net Sales        Price
# 0 Company                NaN       NaN          NaN
#   Facebook              0.80      2.60        155.0
#   Google                5.43     20.00        955.0
#   Microsoft             4.56     18.70         66.0
# 1 Company                NaN       NaN          NaN
#   Facebook              0.97      3.10        150.0
#   Google                5.89     22.00        987.0
#   Microsoft             5.10     21.30         69.0
# 2 Company                NaN       NaN          NaN
#   Facebook              1.20      4.30        153.0
#   Google                6.10     24.00        963.0
#   Microsoft             5.43     21.45         62.0
# 3 Company                NaN       NaN          NaN
#   Facebook              1.67      6.70        155.0
#   Google                6.50     26.00       1000.0
#   Microsoft             5.89     21.88         61.0
# 4 Company                NaN       NaN          NaN
#   Facebook              2.03      8.10        156.0
#   Google                6.40     31.00       1012.0
#   Microsoft             6.09     22.34         66.0
#
#                                           Unnamed: 0_level_0
#             Price to earnings ratio (P/E) Unnamed: 0_level_1
# 0 Company                             NaN            Q1 2016
#   Facebook                          37.10                NaN
#   Google                            32.00                NaN
#   Microsoft                         30.31                NaN
# 1 Company                             NaN            Q2 2016
#   Facebook                          36.98                NaN
#   Google                            31.30                NaN
#   Microsoft                         30.56                NaN
# 2 Company                             NaN            Q3 2016
#   Facebook                          36.78                NaN
#   Google                            31.70                NaN
#   Microsoft                         30.46                NaN
# 3 Company                             NaN            Q4 2016
#   Facebook                          36.11                NaN
#   Google                            31.20                NaN
#   Microsoft                         30.11                NaN
# 4 Company                             NaN            Q1 2017
#   Facebook                          37.07                NaN
#   Google                            30.00                NaN
#   Microsoft                         31.00                NaN

# %%
df2.stack(level=0)
# Out:
#                      Net Profit                  Net Sales                   \
#                        Facebook Google Microsoft  Facebook Google Microsoft
# 0 Income Statement         0.80   5.43      4.56       2.6   20.0     18.70
#   Price Ratios              NaN    NaN       NaN       NaN    NaN       NaN
#   Unnamed: 0_level_0        NaN    NaN       NaN       NaN    NaN       NaN
# 1 Income Statement         0.97   5.89      5.10       3.1   22.0     21.30
#   Price Ratios              NaN    NaN       NaN       NaN    NaN       NaN
#   Unnamed: 0_level_0        NaN    NaN       NaN       NaN    NaN       NaN
# 2 Income Statement         1.20   6.10      5.43       4.3   24.0     21.45
#   Price Ratios              NaN    NaN       NaN       NaN    NaN       NaN
#   Unnamed: 0_level_0        NaN    NaN       NaN       NaN    NaN       NaN
# 3 Income Statement         1.67   6.50      5.89       6.7   26.0     21.88
#   Price Ratios              NaN    NaN       NaN       NaN    NaN       NaN
#   Unnamed: 0_level_0        NaN    NaN       NaN       NaN    NaN       NaN
# 4 Income Statement         2.03   6.40      6.09       8.1   31.0     22.34
#   Price Ratios              NaN    NaN       NaN       NaN    NaN       NaN
#   Unnamed: 0_level_0        NaN    NaN       NaN       NaN    NaN       NaN
#
#                         Price                   Price to earnings ratio (P/E)  \
#                      Facebook  Google Microsoft                      Facebook
# 0 Income Statement        NaN     NaN       NaN                           NaN
#   Price Ratios          155.0   955.0      66.0                         37.10
#   Unnamed: 0_level_0      NaN     NaN       NaN                           NaN
# 1 Income Statement        NaN     NaN       NaN                           NaN
#   Price Ratios          150.0   987.0      69.0                         36.98
#   Unnamed: 0_level_0      NaN     NaN       NaN                           NaN
# 2 Income Statement        NaN     NaN       NaN                           NaN
#   Price Ratios          153.0   963.0      62.0                         36.78
#   Unnamed: 0_level_0      NaN     NaN       NaN                           NaN
# 3 Income Statement        NaN     NaN       NaN                           NaN
#   Price Ratios          155.0  1000.0      61.0                         36.11
#   Unnamed: 0_level_0      NaN     NaN       NaN                           NaN
# 4 Income Statement        NaN     NaN       NaN                           NaN
#   Price Ratios          156.0  1012.0      66.0                         37.07
#   Unnamed: 0_level_0      NaN     NaN       NaN                           NaN
#
#                                       Unnamed: 0_level_1
#                      Google Microsoft            Company
# 0 Income Statement      NaN       NaN                NaN
#   Price Ratios         32.0     30.31                NaN
#   Unnamed: 0_level_0    NaN       NaN            Q1 2016
# 1 Income Statement      NaN       NaN                NaN
#   Price Ratios         31.3     30.56                NaN
#   Unnamed: 0_level_0    NaN       NaN            Q2 2016
# 2 Income Statement      NaN       NaN                NaN
#   Price Ratios         31.7     30.46                NaN
#   Unnamed: 0_level_0    NaN       NaN            Q3 2016
# 3 Income Statement      NaN       NaN                NaN
#   Price Ratios         31.2     30.11                NaN
#   Unnamed: 0_level_0    NaN       NaN            Q4 2016
# 4 Income Statement      NaN       NaN                NaN
#   Price Ratios         30.0     31.00                NaN
#   Unnamed: 0_level_0    NaN       NaN            Q1 2017

# %%
df2.stack(level=1)
# Out:
#                                 Income Statement                   \
#                                         Facebook Google Microsoft
# 0 Net Profit                                0.80   5.43      4.56
#   Net Sales                                 2.60  20.00     18.70
#   Price                                      NaN    NaN       NaN
#   Price to earnings ratio (P/E)              NaN    NaN       NaN
#   Unnamed: 0_level_1                         NaN    NaN       NaN
# 1 Net Profit                                0.97   5.89      5.10
#   Net Sales                                 3.10  22.00     21.30
#   Price                                      NaN    NaN       NaN
#   Price to earnings ratio (P/E)              NaN    NaN       NaN
#   Unnamed: 0_level_1                         NaN    NaN       NaN
# 2 Net Profit                                1.20   6.10      5.43
#   Net Sales                                 4.30  24.00     21.45
#   Price                                      NaN    NaN       NaN
#   Price to earnings ratio (P/E)              NaN    NaN       NaN
#   Unnamed: 0_level_1                         NaN    NaN       NaN
# 3 Net Profit                                1.67   6.50      5.89
#   Net Sales                                 6.70  26.00     21.88
#   Price                                      NaN    NaN       NaN
#   Price to earnings ratio (P/E)              NaN    NaN       NaN
#   Unnamed: 0_level_1                         NaN    NaN       NaN
# 4 Net Profit                                2.03   6.40      6.09
#   Net Sales                                 8.10  31.00     22.34
#   Price                                      NaN    NaN       NaN
#   Price to earnings ratio (P/E)              NaN    NaN       NaN
#   Unnamed: 0_level_1                         NaN    NaN       NaN
#
#                                 Price Ratios                    \
#                                     Facebook  Google Microsoft
# 0 Net Profit                             NaN     NaN       NaN
#   Net Sales                              NaN     NaN       NaN
#   Price                               155.00   955.0     66.00
#   Price to earnings ratio (P/E)        37.10    32.0     30.31
#   Unnamed: 0_level_1                     NaN     NaN       NaN
# 1 Net Profit                             NaN     NaN       NaN
#   Net Sales                              NaN     NaN       NaN
#   Price                               150.00   987.0     69.00
#   Price to earnings ratio (P/E)        36.98    31.3     30.56
#   Unnamed: 0_level_1                     NaN     NaN       NaN
# 2 Net Profit                             NaN     NaN       NaN
#   Net Sales                              NaN     NaN       NaN
#   Price                               153.00   963.0     62.00
#   Price to earnings ratio (P/E)        36.78    31.7     30.46
#   Unnamed: 0_level_1                     NaN     NaN       NaN
# 3 Net Profit                             NaN     NaN       NaN
#   Net Sales                              NaN     NaN       NaN
#   Price                               155.00  1000.0     61.00
#   Price to earnings ratio (P/E)        36.11    31.2     30.11
#   Unnamed: 0_level_1                     NaN     NaN       NaN
# 4 Net Profit                             NaN     NaN       NaN
#   Net Sales                              NaN     NaN       NaN
#   Price                               156.00  1012.0     66.00
#   Price to earnings ratio (P/E)        37.07    30.0     31.00
#   Unnamed: 0_level_1                     NaN     NaN       NaN
#
#                                 Unnamed: 0_level_0
#                                            Company
# 0 Net Profit                                   NaN
#   Net Sales                                    NaN
#   Price                                        NaN
#   Price to earnings ratio (P/E)                NaN
#   Unnamed: 0_level_1                       Q1 2016
# 1 Net Profit                                   NaN
#   Net Sales                                    NaN
#   Price                                        NaN
#   Price to earnings ratio (P/E)                NaN
#   Unnamed: 0_level_1                       Q2 2016
# 2 Net Profit                                   NaN
#   Net Sales                                    NaN
#   Price                                        NaN
#   Price to earnings ratio (P/E)                NaN
#   Unnamed: 0_level_1                       Q3 2016
# 3 Net Profit                                   NaN
#   Net Sales                                    NaN
#   Price                                        NaN
#   Price to earnings ratio (P/E)                NaN
#   Unnamed: 0_level_1                       Q4 2016
# 4 Net Profit                                   NaN
#   Net Sales                                    NaN
#   Price                                        NaN
#   Price to earnings ratio (P/E)                NaN
#   Unnamed: 0_level_1                       Q1 2017

# %% [markdown]
# <h1 style="color:blue" align="center">Crosstab Tutorial</h1>

# %%
import pandas as pd
df = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\13b.xls")
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Nationality,df.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab(df.Sex,df.Handedness)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %% [markdown]
# <h2 style="color:purple">Margins</h2>

# %%
pd.crosstab(df.Sex,df.Handedness, margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %% [markdown]
# <h2 style="color:purple">Multi Index Column and Rows</h2>

# %%
pd.crosstab(df.Sex, [df.Handedness,df.Nationality], margins=True)
# Out:
# Handedness       Left                 Right           All
# Nationality Bangadesh China India USA China India USA
# Sex
# Female              1     1     0   0     1     0   2   5
# Male                1     1     2   1     0     1   1   7
# All                 2     2     2   1     1     1   3  12

# %%
pd.crosstab([df.Nationality, df.Sex], [df.Handedness], margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangadesh   Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %% [markdown]
# <h2 style="color:purple">Normalize</h2>

# %%
pd.crosstab(df.Sex, df.Handedness, normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.400000  0.600000
# Male        0.714286  0.285714

# %% [markdown]
# <h2 style="color:purple">Aggfunc and Values</h2>

# %%
import numpy as np
pd.crosstab(df.Sex, df.Handedness, values=df.Age, aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %% [markdown]
# <h1 style="color:blue" align="center">Pandas Time Series Tutorial: DateTimeIndex</h1>

# %%
df=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\14b.csv",parse_dates=["Date"], index_col="Date")
df.head(2)
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %% [markdown]
# <h3 style="color:purple">What is DatetimeIndex? Benefits of it</h3>

# %% [markdown]
# <h4> (1) Partial Date Index: Select Specific Months Data</h4>

# %%
df.loc['2017-06-30']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df.loc["2017-01"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# 2017-01-13  119.11  119.62  118.81  119.04  26111948
# 2017-01-12  118.90  119.30  118.21  119.25  27086220
# 2017-01-11  118.74  119.93  118.60  119.75  27588593
# 2017-01-10  118.77  119.38  118.30  119.11  24462051
# 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %%
df.loc['2017-06'].head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29  144.71  145.13  142.28  143.68  31499368
# 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-26  147.17  148.28  145.38  145.82  25692361

# %% [markdown]
# <h4>Average price of aapl's stock in June, 2017</h4>

# %%
df.loc['2017-06'].Close.mean()
# Out:
# 147.8313636363636

# %%
df['2017'].head(2)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9468/1799195107.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017'].head(2)
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782

# %% [markdown]
# <h4>(2) Select Date Range</h4>

# %%
df['2017-01-08':'2017-01-03']
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume]
# Index: []

# %%
df.loc['2017-01']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# 2017-01-13  119.11  119.62  118.81  119.04  26111948
# 2017-01-12  118.90  119.30  118.21  119.25  27086220
# 2017-01-11  118.74  119.93  118.60  119.75  27588593
# 2017-01-10  118.77  119.38  118.30  119.11  24462051
# 2017-01-09  117.95  119.43  117.94  118.99  33561948
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %% [markdown]
# <h3 style="color:purple">Resampling</h3>

# %%
df['Close'].resample('M').mean().head()
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# Freq: M, Name: Close, dtype: float64

# %%
df['2016-07']
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9468/2659590539.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2016-07']
#               Open    High     Low   Close    Volume
# Date
# 2016-07-29  104.19  104.55  103.68  104.21  27733688
# 2016-07-28  102.83  104.45  102.82  104.34  39869839
# 2016-07-27  104.26  104.35  102.75  102.95  92344820
# 2016-07-26   96.82   97.97   96.42   96.67  56239822
# 2016-07-25   98.25   98.84   96.92   97.34  40382921
# 2016-07-22   99.26   99.30   98.31   98.66  28313669
# 2016-07-21   99.83  101.00   99.13   99.43  32702028
# 2016-07-20  100.00  100.46   99.74   99.96  26275968
# 2016-07-19   99.56  100.00   99.34   99.87  23779924
# 2016-07-18   98.70  100.13   98.60   99.83  36493867
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945

# %%
# %matplotlib inline
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].resample('M').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# <h1 style="color:blue;" align="center">Pandas Time Series Analysis Tutorial: date_range</h1>

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\15b.csv")
df.head()
# Out:
#        Date    Open    High     Low   Close    Volume
# 0  1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 1  2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2  5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 3  6-Jun-17  153.90  155.81  153.78  154.45  26624926
# 4  7-Jun-17  155.02  155.98  154.48  155.37  21069647

# %%
rng = pd.date_range(start="6/1/2016",end="6/30/2016",freq='B')
rng
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index(rng, inplace=True)
df.head()
# Out:
#                 Date    Open    High     Low   Close    Volume
# 2016-06-01  1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  6-Jun-17  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  7-Jun-17  155.02  155.98  154.48  155.37  21069647

# %% [markdown]
# <h3 style="color:purple">Finding missing dates from datetimeindex</h3>

# %%
daily_index = pd.date_range(start="6/1/2016",end="6/30/2016",freq='D')
daily_index
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-04',
#                '2016-06-05', '2016-06-06', '2016-06-07', '2016-06-08',
#                '2016-06-09', '2016-06-10', '2016-06-11', '2016-06-12',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-18', '2016-06-19', '2016-06-20',
#                '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24',
#                '2016-06-25', '2016-06-26', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
daily_index.difference(df.index)
# Out:
# DatetimeIndex(['2016-06-04', '2016-06-05', '2016-06-11', '2016-06-12',
#                '2016-06-18', '2016-06-19', '2016-06-25', '2016-06-26'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# <h3 style="color:purple">Benefits of having DatetimeIndex</h3>

# %%
# %matplotlib inline
df.Close.plot()
# Out:
# <AxesSubplot:>

# %%
df["2016-06-01":"2016-06-10"].Close.mean()
# Out:
# 152.72125

# %% [markdown]
# <h3 style="color:purple">as freq</h3>

# %%
df.index
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.asfreq('D',method='pad')
# Out:
#                  Date    Open    High     Low   Close    Volume
# 2016-06-01   1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 2016-06-02   2-Jun-17  153.58  155.45  152.89  155.45  27770715
# 2016-06-03   5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 2016-06-04   5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 2016-06-05   5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 2016-06-06   6-Jun-17  153.90  155.81  153.78  154.45  26624926
# 2016-06-07   7-Jun-17  155.02  155.98  154.48  155.37  21069647
# 2016-06-08   8-Jun-17  155.25  155.54  154.40  154.99  21250798
# 2016-06-09   9-Jun-17  155.19  155.19  146.02  148.98  64882657
# 2016-06-10  12-Jun-17  145.74  146.09  142.51  145.42  72307330
# 2016-06-11  12-Jun-17  145.74  146.09  142.51  145.42  72307330
# 2016-06-12  12-Jun-17  145.74  146.09  142.51  145.42  72307330
# 2016-06-13  13-Jun-17  147.16  147.45  145.15  146.59  34165445
# 2016-06-14  14-Jun-17  147.50  147.50  143.84  145.16  31531232
# 2016-06-15  15-Jun-17  143.32  144.48  142.21  144.29  32165373
# 2016-06-16  16-Jun-17  143.78  144.50  142.20  142.27  50361093
# 2016-06-17  19-Jun-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-18  19-Jun-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-19  19-Jun-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-20  20-Jun-17  146.87  146.87  144.94  145.01  24900073
# 2016-06-21  21-Jun-17  145.52  146.07  144.61  145.87  21265751
# 2016-06-22  22-Jun-17  145.77  146.70  145.12  145.63  19106294
# 2016-06-23  23-Jun-17  145.13  147.16  145.11  146.28  35439389
# 2016-06-24  26-Jun-17  147.17  148.28  145.38  145.82  25692361
# 2016-06-25  26-Jun-17  147.17  148.28  145.38  145.82  25692361
# 2016-06-26  26-Jun-17  147.17  148.28  145.38  145.82  25692361
# 2016-06-27  27-Jun-17  145.01  146.16  143.62  143.73  24761891
# 2016-06-28  28-Jun-17  144.49  146.11  143.16  145.83  22082432
# 2016-06-29  29-Jun-17  144.71  145.13  142.28  143.68  31499368
# 2016-06-30  30-Jun-17  144.45  144.96  143.78  144.02  23024107

# %%
df.asfreq('W',method='pad')
# Out:
#                  Date    Open    High     Low   Close    Volume
# 2016-06-05   5-Jun-17  154.34  154.45  153.46  153.93  25331662
# 2016-06-12  12-Jun-17  145.74  146.09  142.51  145.42  72307330
# 2016-06-19  19-Jun-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-26  26-Jun-17  147.17  148.28  145.38  145.82  25692361

# %%
df.asfreq('H',method='pad')
# Out:
#                           Date    Open    High     Low   Close    Volume
# 2016-06-01 00:00:00   1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 01:00:00   1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 02:00:00   1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 03:00:00   1-Jun-17  153.17  153.33  152.22  153.18  16404088
# 2016-06-01 04:00:00   1-Jun-17  153.17  153.33  152.22  153.18  16404088
# ...                        ...     ...     ...     ...     ...       ...
# 2016-06-29 20:00:00  29-Jun-17  144.71  145.13  142.28  143.68  31499368
# 2016-06-29 21:00:00  29-Jun-17  144.71  145.13  142.28  143.68  31499368
# 2016-06-29 22:00:00  29-Jun-17  144.71  145.13  142.28  143.68  31499368
# 2016-06-29 23:00:00  29-Jun-17  144.71  145.13  142.28  143.68  31499368
# 2016-06-30 00:00:00  30-Jun-17  144.45  144.96  143.78  144.02  23024107
#
# [697 rows x 6 columns]

# %% [markdown]
# <h3 style="color:purple"> generating DatetimeIndex with periods argument</h3>

# %%
rng = pd.date_range('1/1/2011', periods=72, freq='H')
rng
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                '2011-01-01 10:00:00', '2011-01-01 11:00:00',
#                '2011-01-01 12:00:00', '2011-01-01 13:00:00',
#                '2011-01-01 14:00:00', '2011-01-01 15:00:00',
#                '2011-01-01 16:00:00', '2011-01-01 17:00:00',
#                '2011-01-01 18:00:00', '2011-01-01 19:00:00',
#                '2011-01-01 20:00:00', '2011-01-01 21:00:00',
#                '2011-01-01 22:00:00', '2011-01-01 23:00:00',
#                '2011-01-02 00:00:00', '2011-01-02 01:00:00',
#                '2011-01-02 02:00:00', '2011-01-02 03:00:00',
#                '2011-01-02 04:00:00', '2011-01-02 05:00:00',
#                '2011-01-02 06:00:00', '2011-01-02 07:00:00',
#                '2011-01-02 08:00:00', '2011-01-02 09:00:00',
#                '2011-01-02 10:00:00', '2011-01-02 11:00:00',
#                '2011-01-02 12:00:00', '2011-01-02 13:00:00',
#                '2011-01-02 14:00:00', '2011-01-02 15:00:00',
#                '2011-01-02 16:00:00', '2011-01-02 17:00:00',
#                '2011-01-02 18:00:00', '2011-01-02 19:00:00',
#                '2011-01-02 20:00:00', '2011-01-02 21:00:00',
#                '2011-01-02 22:00:00', '2011-01-02 23:00:00',
#                '2011-01-03 00:00:00', '2011-01-03 01:00:00',
#                '2011-01-03 02:00:00', '2011-01-03 03:00:00',
#                '2011-01-03 04:00:00', '2011-01-03 05:00:00',
#                '2011-01-03 06:00:00', '2011-01-03 07:00:00',
#                '2011-01-03 08:00:00', '2011-01-03 09:00:00',
#                '2011-01-03 10:00:00', '2011-01-03 11:00:00',
#                '2011-01-03 12:00:00', '2011-01-03 13:00:00',
#                '2011-01-03 14:00:00', '2011-01-03 15:00:00',
#                '2011-01-03 16:00:00', '2011-01-03 17:00:00',
#                '2011-01-03 18:00:00', '2011-01-03 19:00:00',
#                '2011-01-03 20:00:00', '2011-01-03 21:00:00',
#                '2011-01-03 22:00:00', '2011-01-03 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
import numpy as np
ts = pd.Series(np.random.randint(0,10,len(rng)), index=rng)
ts.head(20)
# Out:
# 2011-01-01 00:00:00    0
# 2011-01-01 01:00:00    3
# 2011-01-01 02:00:00    5
# 2011-01-01 03:00:00    6
# 2011-01-01 04:00:00    8
# 2011-01-01 05:00:00    5
# 2011-01-01 06:00:00    0
# 2011-01-01 07:00:00    1
# 2011-01-01 08:00:00    5
# 2011-01-01 09:00:00    8
# 2011-01-01 10:00:00    2
# 2011-01-01 11:00:00    8
# 2011-01-01 12:00:00    7
# 2011-01-01 13:00:00    3
# 2011-01-01 14:00:00    4
# 2011-01-01 15:00:00    1
# 2011-01-01 16:00:00    1
# 2011-01-01 17:00:00    9
# 2011-01-01 18:00:00    8
# 2011-01-01 19:00:00    2
# Freq: H, dtype: int32

# %% [markdown]
# <h1 style="color:blue" align="center">Pandas Time Series Analysis Tutorial: Handling Holidays</h1>

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\16b.csv")
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0   3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 1   5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 2   6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 3   7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 4  10-Jul-17  144.11  145.95  143.37  145.06  21090636

# %%
rng = pd.date_range(start="7/1/2017", end="7/21/2017", freq='B')
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# **Using 'B' frequency is not going to help because 4th July was holiday and 'B' is not taking that into account.
# It only accounts for weekends**

# %% [markdown]
# <h3 style="color:purple">Using CustomBusinessDay to generate US holidays calendar frequency</h3>

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

us_cal = CustomBusinessDay(calendar=USFederalHolidayCalendar())

rng = pd.date_range(start="7/1/2017",end="7/23/2017", freq=us_cal)
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='C')

# %%
df.set_index(rng,inplace=True)
df.head()
# Out:
#                  Date    Open    High     Low   Close    Volume
# 2017-07-03   3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 2017-07-05   5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 2017-07-06   6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2017-07-07   7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 2017-07-10  10-Jul-17  144.11  145.95  143.37  145.06  21090636

# %% [markdown]
# **You can define your own calendar using AbstractHolidayCalendar as shown below. USFederalHolidayCalendar is the only calendar available in pandas library and it serves as an example for those who want to write their own custom calendars. Here is the link for USFederalHolidayCalendar implementation** https://github.com/pandas-dev/pandas/blob/master/pandas/tseries/holiday.py

# %% [markdown]
# <h3 style="color:purple">AbstractHolidayCalendar</h3>

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=4, day=15),#, observance=nearest_workday),
    ]
    
my_bday = CustomBusinessDay(calendar=myCalendar())
pd.date_range('4/1/2017','4/30/2017',freq=my_bday)
# Out:
# DatetimeIndex(['2017-04-03', '2017-04-04', '2017-04-05', '2017-04-06',
#                '2017-04-07', '2017-04-10', '2017-04-11', '2017-04-12',
#                '2017-04-13', '2017-04-14', '2017-04-17', '2017-04-18',
#                '2017-04-19', '2017-04-20', '2017-04-21', '2017-04-24',
#                '2017-04-25', '2017-04-26', '2017-04-27', '2017-04-28'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# <h3 style="color:purple">CustomBusinessDay</h3>

# %% [markdown]
# **Weekend in egypt is Friday and Saturday. Sunday is just a normal weekday and you can handle this custom week schedule using
# CystomBysinessDay with weekmask as shown below**

# %%
egypt_weekdays = "Sun Mon Tue Wed Thu"

b = CustomBusinessDay(weekmask=egypt_weekdays)

pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-12', '2017-07-13', '2017-07-16', '2017-07-17',
#                '2017-07-18', '2017-07-19', '2017-07-20', '2017-07-23',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# **You can also add holidays to this custom business day frequency**

# %%
b = CustomBusinessDay(holidays=['2017-07-04', '2017-07-10'], weekmask=egypt_weekdays)

pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-09', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-16', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-23', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-30', '2017-07-31'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# **Mathematical operations on date object using custom business day**

# %%
from datetime import datetime
dt = datetime(2017,7,9)
dt
# Out:
# datetime.datetime(2017, 7, 9, 0, 0)

# %%
dt + 1*b
# Out:
# Timestamp('2017-07-11 00:00:00')

# %% [markdown]
# <h1 style="color:blue" align="center">Pandas Time Series Analysis Tutorial: to_datetime</h1>

# %%
import pandas as pd
dates = ['2017-01-05', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-05', '2017-01-05', '2017-01-05',
#                '2017-01-05', '2017-01-05'],
#               dtype='datetime64[ns]', freq=None)

# %%
dt = ['2017-01-05 2:30:00 PM', 'Jan 5, 2017 14:30:00', '01/05/2016', '2017.01.05', '2017/01/05','20170105']
pd.to_datetime(dt)
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 14:30:00',
#                '2016-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# <h3 style="color:purple">European style dates with day first</h3>

# %%
pd.to_datetime('30-12-2016')
# Out:
# Timestamp('2016-12-30 00:00:00')

# %%
pd.to_datetime('5-1-2016', dayfirst=True)
# Out:
# Timestamp('2016-01-05 00:00:00')

# %% [markdown]
# <h3 style="color:purple">Custom date time format</h3>

# %%
pd.to_datetime('2017$01$05', format='%Y$%m$%d')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
pd.to_datetime('2017#01#05', format='%Y#%m#%d')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %% [markdown]
# <h3 style="color:purple">Handling invalid dates</h3>

# %%
pd.to_datetime(['2017-01-05', 'Jan 6, 2017', 'abc'], errors='ignore')
# Out:
# Index(['2017-01-05', 'Jan 6, 2017', 'abc'], dtype='object')

# %%
pd.to_datetime(['2017-01-05', 'Jan 6, 2017', 'abc'], errors='coerce')
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-06', 'NaT'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# <h3 style="color:purple">Epoch</h3>

# %% [markdown]
# **Epoch or Unix time means number of seconds that have passed since Jan 1, 1970 00:00:00 UTC time**

# %%
current_epoch = 1501324478
pd.to_datetime(current_epoch, unit='s')
# Out:
# Timestamp('2017-07-29 10:34:38')

# %%
pd.to_datetime(current_epoch*1000, unit='ms')
# Out:
# Timestamp('2017-07-29 10:34:38')

# %%
t = pd.to_datetime([current_epoch], unit='s')
t
# Out:
# DatetimeIndex(['2017-07-29 10:34:38'], dtype='datetime64[ns]', freq=None)

# %%
t.view('int64')
# Out:
# array([1501324478000000000], dtype=int64)

# %% [markdown]
# <h1 style="color:blue" align="center">Pandas Time Series Analysis: Period and PeriodIndex</h1>

# %% [markdown]
# <h3 style="color:purple">Yearly Period</h3>

# %%
import pandas as pd
y = pd.Period('2016')
y
# Out:
# Period('2016', 'A-DEC')

# %%
y.start_time
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
y.end_time
# Out:
# Timestamp('2016-12-31 23:59:59.999999999')

# %%
y.is_leap_year
# Out:
# True

# %% [markdown]
# <h3 style="color:purple">Monthly Period</h3>

# %%
m = pd.Period('2017-12')
m
# Out:
# Period('2017-12', 'M')

# %%
m.start_time
# Out:
# Timestamp('2017-12-01 00:00:00')

# %%
m.end_time
# Out:
# Timestamp('2017-12-31 23:59:59.999999999')

# %%
m+1
# Out:
# Period('2018-01', 'M')

# %% [markdown]
# <h3 style="color:purple">Daily Period</h3>

# %%
d = pd.Period('2016-02-28', freq='D')
d
# Out:
# Period('2016-02-28', 'D')

# %%
d.start_time
# Out:
# Timestamp('2016-02-28 00:00:00')

# %%
d.end_time
# Out:
# Timestamp('2016-02-28 23:59:59.999999999')

# %%
d+1
# Out:
# Period('2016-02-29', 'D')

# %% [markdown]
# <h3 style="color:purple">Hourly Period</h3>

# %%
h = pd.Period('2017-08-15 23:00:00',freq='H')
h
# Out:
# Period('2017-08-15 23:00', 'H')

# %%
h+1
# Out:
# Period('2017-08-16 00:00', 'H')

# %% [markdown]
# <h4>Achieve same results using pandas offsets hour</h4>

# %%
h+pd.offsets.Hour(1)
# Out:
# Period('2017-08-16 00:00', 'H')

# %% [markdown]
# <h3 style="color:purple">Quarterly Period</h3>

# %%
q1= pd.Period('2017Q1', freq='Q-JAN')
q1
# Out:
# Period('2017Q1', 'Q-JAN')

# %%
q1.start_time
# Out:
# Timestamp('2016-02-01 00:00:00')

# %%
q1.end_time
# Out:
# Timestamp('2016-04-30 23:59:59.999999999')

# %% [markdown]
# <h4>Use asfreq to convert period to a different frequency</h4>

# %%
q1.asfreq('M',how='start')
# Out:
# Period('2016-02', 'M')

# %%
q1.asfreq('M',how='end')
# Out:
# Period('2016-04', 'M')

# %% [markdown]
# <h3 style="color:purple">Weekly Period</h3>

# %%
w = pd.Period('2017-07-05',freq='W')
w
# Out:
# Period('2017-07-03/2017-07-09', 'W-SUN')

# %%
w-1
# Out:
# Period('2017-06-26/2017-07-02', 'W-SUN')

# %%
w2 = pd.Period('2017-08-15',freq='W')
w2
# Out:
# Period('2017-08-14/2017-08-20', 'W-SUN')

# %%
w2-w
# Out:
# <6 * Weeks: weekday=6>

# %% [markdown]
# <h3 style="color:purple">PeriodIndex and period_range</h3>

# %%
r = pd.period_range('2011', '2017', freq='q')
r
# Out:
# PeriodIndex(['2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2',
#              '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4',
#              '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1', '2015Q2',
#              '2015Q3', '2015Q4', '2016Q1', '2016Q2', '2016Q3', '2016Q4',
#              '2017Q1'],
#             dtype='period[Q-DEC]')

# %%
r[0].start_time
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
r[0].end_time
# Out:
# Timestamp('2011-03-31 23:59:59.999999999')

# %% [markdown]
# **Walmart's fiscal year ends in Jan, below is how you generate walmart's fiscal quarters between 2011 and 2017**

# %%
r = pd.period_range('2011', '2017', freq='q-jan')
r
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3',
#              '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1',
#              '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3',
#              '2017Q4'],
#             dtype='period[Q-JAN]')

# %%
r[0].start_time
# Out:
# Timestamp('2010-11-01 00:00:00')

# %%
r[0].end_time
# Out:
# Timestamp('2011-01-31 23:59:59.999999999')

# %%
r = pd.PeriodIndex(start='2016-01', freq='3M', periods=10)
r

#some error in it
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/826420904.py in <module>
# ----> 1 r = pd.PeriodIndex(start='2016-01', freq='3M', periods=10)
#       2 r
#       3
#       4 #some error in it
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\period.py in __new__(cls, data, ordinal, freq, dtype, copy, name, **fields)
#     230         if not set(fields).issubset(valid_field_set):
#     231             argument = list(set(fields) - valid_field_set)[0]
# --> 232             raise TypeError(f"__new__() got an unexpected keyword argument {argument}")
#     233
#     234         name = maybe_extract_name(name, data, cls)
#
# TypeError: __new__() got an unexpected keyword argument start

# %%
import numpy as np
ps = pd.Series(np.random.randn(len(idx)), idx)
ps
# Out:
# 2017-01-01    0.861025
# 2017-01-02   -1.220648
# 2017-01-03    0.935889
# 2017-01-04    0.156213
# 2017-01-05   -0.568670
# 2017-01-06    1.624703
# 2017-01-07   -1.948402
# 2017-01-08    0.594283
# 2017-01-09   -0.037746
# 2017-01-10   -0.836525
# 2017-01-11    0.517735
# Freq: D, dtype: float64

# %% [markdown]
# <h4>Partial Indexing</h4>

# %%
ps['2017']
# Out:
# 2017-01-01    0.861025
# 2017-01-02   -1.220648
# 2017-01-03    0.935889
# 2017-01-04    0.156213
# 2017-01-05   -0.568670
# 2017-01-06    1.624703
# 2017-01-07   -1.948402
# 2017-01-08    0.594283
# 2017-01-09   -0.037746
# 2017-01-10   -0.836525
# 2017-01-11    0.517735
# Freq: D, dtype: float64

# %%
ps['2016':'2017']
# Out:
# 2017-01-01    0.861025
# 2017-01-02   -1.220648
# 2017-01-03    0.935889
# 2017-01-04    0.156213
# 2017-01-05   -0.568670
# 2017-01-06    1.624703
# 2017-01-07   -1.948402
# 2017-01-08    0.594283
# 2017-01-09   -0.037746
# 2017-01-10   -0.836525
# 2017-01-11    0.517735
# Freq: D, dtype: float64

# %% [markdown]
# <h4>Converting between representations</h4>

# %%
pst = ps.to_timestamp()
pst

#some error

# %%
pst.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/473576139.py in <module>
# ----> 1 pst.index
#
# NameError: name 'pst' is not defined

# %%
ps = pst.to_period()
ps
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/3418262531.py in <module>
# ----> 1 ps = pst.to_period()
#       2 ps
#
# NameError: name 'pst' is not defined

# %%
ps.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# <h3 style="color:purple">Processing Wal Mart's Financials</h3>

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\18b.csv")
df
# Out:
#   Line Item  2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# 0   Revenue  115904  120854  118179  130936  117542
# 1  Expenses   86544   89485   87484   97743   87688
# 2    Profit   29360   31369   30695   33193   29854

# %%
df.set_index("Line Item",inplace=True)
df = df.T
df
# Out:
# Line Item  Revenue  Expenses  Profit
# 2017Q1      115904     86544   29360
# 2017Q2      120854     89485   31369
# 2017Q3      118179     87484   30695
# 2017Q4      130936     97743   33193
# 2018Q1      117542     87688   29854

# %%
df.index = pd.PeriodIndex(df.index, freq="Q-JAN")
df
# Out:
# Line Item  Revenue  Expenses  Profit
# 2017Q1      115904     86544   29360
# 2017Q2      120854     89485   31369
# 2017Q3      118179     87484   30695
# 2017Q4      130936     97743   33193
# 2018Q1      117542     87688   29854

# %%
df.index
# Out:
# PeriodIndex(['2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1'], dtype='period[Q-JAN]')

# %%
df.index[0].start_time
# Out:
# Timestamp('2016-02-01 00:00:00')

# %% [markdown]
# <h4 style="color:green">Add start date end date columns to dataframe</h4>

# %%
df["Start Date"]=df.index.map(lambda x: x.start_time)
df
# Out:
# Line Item  Revenue  Expenses  Profit Start Date
# 2017Q1      115904     86544   29360 2016-02-01
# 2017Q2      120854     89485   31369 2016-05-01
# 2017Q3      118179     87484   30695 2016-08-01
# 2017Q4      130936     97743   33193 2016-11-01
# 2018Q1      117542     87688   29854 2017-02-01

# %%
df["End Date"]=df.index.map(lambda x: x.end_time)
df
# Out:
# Line Item  Revenue  Expenses  Profit Start Date                      End Date
# 2017Q1      115904     86544   29360 2016-02-01 2016-04-30 23:59:59.999999999
# 2017Q2      120854     89485   31369 2016-05-01 2016-07-31 23:59:59.999999999
# 2017Q3      118179     87484   30695 2016-08-01 2016-10-31 23:59:59.999999999
# 2017Q4      130936     97743   33193 2016-11-01 2017-01-31 23:59:59.999999999
# 2018Q1      117542     87688   29854 2017-02-01 2017-04-30 23:59:59.999999999

# %% [markdown]
# <h1 style="color:blue" align="center">Pandas Time Series Analysis: Handling Time Zones</h1>

# %% [markdown]
# **We live in a world with different timezones. If you are having morning coffee in new york at 9 AM it might be a time for dinner in Mumbai, India because it would be 6.30 PM there. Handling time zone could become necessity while doing time series analysis in Pandas**

# %% [markdown]
# <img src="timezones_world_map.png" />

# %% [markdown]
# **Read microsoft's intraday stock prize**

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\19c.csv", header=1,index_col='Date Time',parse_dates=True)
df
# Out:
#                      Price
# Date Time
# 2017-08-17 09:00:00  72.38
# 2017-08-17 09:15:00  71.00
# 2017-08-17 09:30:00  71.67
# 2017-08-17 10:00:00  72.80
# 2017-08-17 10:30:00  73.00
# 2017-08-17 11:00:00  72.50

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00', '2017-08-17 09:15:00',
#                '2017-08-17 09:30:00', '2017-08-17 10:00:00',
#                '2017-08-17 10:30:00', '2017-08-17 11:00:00'],
#               dtype='datetime64[ns]', name='Date Time', freq=None)

# %% [markdown]
# <h3>Two types of datetimes in python</h3>
# <ol>
#     <li>Naive (no timezone awareness)</li>
#     <li>Timezone aware datetime</li>
# <ol>

# %% [markdown]
# <h3 style="color:purple">Convert naive DatetimeIndex to timezone aware DatetimeIndex using tz_localize</h3>

# %%
df.tz_localize(tz='US/Eastern')
df
# Out:
#                      Price
# Date Time
# 2017-08-17 09:00:00  72.38
# 2017-08-17 09:15:00  71.00
# 2017-08-17 09:30:00  71.67
# 2017-08-17 10:00:00  72.80
# 2017-08-17 10:30:00  73.00
# 2017-08-17 11:00:00  72.50

# %%
df.index = df.index.tz_localize(tz='US/Eastern')
df.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00-04:00', '2017-08-17 09:15:00-04:00',
#                '2017-08-17 09:30:00-04:00', '2017-08-17 10:00:00-04:00',
#                '2017-08-17 10:30:00-04:00', '2017-08-17 11:00:00-04:00'],
#               dtype='datetime64[ns, US/Eastern]', name='Date Time', freq=None)

# %% [markdown]
# <h3 style="color:purple">Convert to Berlin time using tz_convert</h3>

# %%
df = df.tz_convert('Europe/Berlin')
df
# Out:
#                            Price
# Date Time
# 2017-08-17 15:00:00+02:00  72.38
# 2017-08-17 15:15:00+02:00  71.00
# 2017-08-17 15:30:00+02:00  71.67
# 2017-08-17 16:00:00+02:00  72.80
# 2017-08-17 16:30:00+02:00  73.00
# 2017-08-17 17:00:00+02:00  72.50

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-17 15:00:00+02:00', '2017-08-17 15:15:00+02:00',
#                '2017-08-17 15:30:00+02:00', '2017-08-17 16:00:00+02:00',
#                '2017-08-17 16:30:00+02:00', '2017-08-17 17:00:00+02:00'],
#               dtype='datetime64[ns, Europe/Berlin]', name='Date Time', freq=None)

# %%
from pytz import all_timezones
print (all_timezones)
# Out:
# ['Africa/Abidjan', 'Africa/Accra', 'Africa/Addis_Ababa', 'Africa/Algiers', 'Africa/Asmara', 'Africa/Asmera', 'Africa/Bamako', 'Africa/Bangui', 'Africa/Banjul', 'Africa/Bissau', 'Africa/Blantyre', 'Africa/Brazzaville', 'Africa/Bujumbura', 'Africa/Cairo', 'Africa/Casablanca', 'Africa/Ceuta', 'Africa/Conakry', 'Africa/Dakar', 'Africa/Dar_es_Salaam', 'Africa/Djibouti', 'Africa/Douala', 'Africa/El_Aaiun', 'Africa/Freetown', 'Africa/Gaborone', 'Africa/Harare', 'Africa/Johannesburg', 'Africa/Juba', 'Africa/Kampala', 'Africa/Khartoum', 'Africa/Kigali', 'Africa/Kinshasa', 'Africa/Lagos', 'Africa/Libreville', 'Africa/Lome', 'Africa/Luanda', 'Africa/Lubumbashi', 'Africa/Lusaka', 'Africa/Malabo', 'Africa/Maputo', 'Africa/Maseru', 'Africa/Mbabane', 'Africa/Mogadishu', 'Africa/Monrovia', 'Africa/Nairobi', 'Africa/Ndjamena', 'Africa/Niamey', 'Africa/Nouakchott', 'Africa/Ouagadougou', 'Africa/Porto-Novo', 'Africa/Sao_Tome', 'Africa/Timbuktu', 'Africa/Tripoli', 'Africa/Tunis', 'Africa/Windhoek', 'America/Adak', 'America/Anchorage', 'America/Anguilla', 'America/Antigua', 'America/Araguaina', 'America/Argentina/Buenos_Aires', 'America/Argentina/Catamarca', 'America/Argentina/ComodRivadavia', 'America/Argentina/Cordoba', 'America/Argentina/Jujuy', 'America/Argentina/La_Rioja', 'America/Argentina/Mendoza', 'America/Argentina/Rio_Gallegos', 'America/Argentina/Salta', 'America/Argentina/San_Juan', 'America/Argentina/San_Luis', 'America/Argentina/Tucuman', 'America/Argentina/Ushuaia', 'America/Aruba', 'America/Asuncion', 'America/Atikokan', 'America/Atka', 'America/Bahia', 'America/Bahia_Banderas', 'America/Barbados', 'America/Belem', 'America/Belize', 'America/Blanc-Sablon', 'America/Boa_Vista', 'America/Bogota', 'America/Boise', 'America/Buenos_Aires', 'America/Cambridge_Bay', 'America/Campo_Grande', 'America/Cancun', 'America/Caracas', 'America/Catamarca', 'America/Cayenne', 'America/Cayman', 'America/Chicago', 'America/Chihuahua', 'America/Coral_Harbour', 'America/Cordoba', 'America/Costa_Rica', 'America/Creston', 'America/Cuiaba', 'America/Curacao', 'America/Danmarkshavn', 'America/Dawson', 'America/Dawson_Creek', 'America/Denver', 'America/Detroit', 'America/Dominica', 'America/Edmonton', 'America/Eirunepe', 'America/El_Salvador', 'America/Ensenada', 'America/Fort_Nelson', 'America/Fort_Wayne', 'America/Fortaleza', 'America/Glace_Bay', 'America/Godthab', 'America/Goose_Bay', 'America/Grand_Turk', 'America/Grenada', 'America/Guadeloupe', 'America/Guatemala', 'America/Guayaquil', 'America/Guyana', 'America/Halifax', 'America/Havana', 'America/Hermosillo', 'America/Indiana/Indianapolis', 'America/Indiana/Knox', 'America/Indiana/Marengo', 'America/Indiana/Petersburg', 'America/Indiana/Tell_City', 'America/Indiana/Vevay', 'America/Indiana/Vincennes', 'America/Indiana/Winamac', 'America/Indianapolis', 'America/Inuvik', 'America/Iqaluit', 'America/Jamaica', 'America/Jujuy', 'America/Juneau', 'America/Kentucky/Louisville', 'America/Kentucky/Monticello', 'America/Knox_IN', 'America/Kralendijk', 'America/La_Paz', 'America/Lima', 'America/Los_Angeles', 'America/Louisville', 'America/Lower_Princes', 'America/Maceio', 'America/Managua', 'America/Manaus', 'America/Marigot', 'America/Martinique', 'America/Matamoros', 'America/Mazatlan', 'America/Mendoza', 'America/Menominee', 'America/Merida', 'America/Metlakatla', 'America/Mexico_City', 'America/Miquelon', 'America/Moncton', 'America/Monterrey', 'America/Montevideo', 'America/Montreal', 'America/Montserrat', 'America/Nassau', 'America/New_York', 'America/Nipigon', 'America/Nome', 'America/Noronha', 'America/North_Dakota/Beulah', 'America/North_Dakota/Center', 'America/North_Dakota/New_Salem', 'America/Nuuk', 'America/Ojinaga', 'America/Panama', 'America/Pangnirtung', 'America/Paramaribo', 'America/Phoenix', 'America/Port-au-Prince', 'America/Port_of_Spain', 'America/Porto_Acre', 'America/Porto_Velho', 'America/Puerto_Rico', 'America/Punta_Arenas', 'America/Rainy_River', 'America/Rankin_Inlet', 'America/Recif ...

# %% [markdown]
# <h3 style="color:purple">Convert to Mumbai time</h3>

# %%
df.index = df.index.tz_convert('Asia/Calcutta') # tz database doesn't have any Mumbai timezone but calcutta and mumbai are both in same timezone so we will use that
df
# Out:
#                            Price
# Date Time
# 2017-08-17 18:30:00+05:30  72.38
# 2017-08-17 18:45:00+05:30  71.00
# 2017-08-17 19:00:00+05:30  71.67
# 2017-08-17 19:30:00+05:30  72.80
# 2017-08-17 20:00:00+05:30  73.00
# 2017-08-17 20:30:00+05:30  72.50

# %% [markdown]
# <h3 style="color:purple">Using timezones in date_range</h3>

# %% [markdown]
# <h4 style="color:green">(1) timezone using pytz</h4>

# %%
london = pd.date_range('3/6/2012 00:09:00', periods=10, freq='H',tz='Europe/London')
london
# Out:
# DatetimeIndex(['2012-03-06 00:09:00+00:00', '2012-03-06 01:09:00+00:00',
#                '2012-03-06 02:09:00+00:00', '2012-03-06 03:09:00+00:00',
#                '2012-03-06 04:09:00+00:00', '2012-03-06 05:09:00+00:00',
#                '2012-03-06 06:09:00+00:00', '2012-03-06 07:09:00+00:00',
#                '2012-03-06 08:09:00+00:00', '2012-03-06 09:09:00+00:00'],
#               dtype='datetime64[ns, Europe/London]', freq='H')

# %% [markdown]
# <h4 style="color:green">(2) timezone using dateutil</h4>

# %%
td = pd.date_range('3/6/2012 00:00', periods=10, freq='H',tz='dateutil/Europe/London')
td
# Out:
# DatetimeIndex(['2012-03-06 00:00:00+00:00', '2012-03-06 01:00:00+00:00',
#                '2012-03-06 02:00:00+00:00', '2012-03-06 03:00:00+00:00',
#                '2012-03-06 04:00:00+00:00', '2012-03-06 05:00:00+00:00',
#                '2012-03-06 06:00:00+00:00', '2012-03-06 07:00:00+00:00',
#                '2012-03-06 08:00:00+00:00', '2012-03-06 09:00:00+00:00'],
#               dtype='datetime64[ns, tzfile('Europe/Belfast')]', freq='H')

# %% [markdown]
# <h3>Pandas documentation indicates that difference between pytz timezone and dateutil timezones is</h3>
# <ol>
#     <li>In pytz you can find a list of common (and less common) time zones using from pytz import common_timezones, all_timezones</li>
#     <li>dateutil uses the OS timezones so there isn’t a fixed list available. For common zones, the names are the same as pytz</li>
# <ol>

# %% [markdown]
# <h3 style="color:purple">Airthmetic between different timezones</h3>

# %%
rng = pd.date_range(start="2017-08-22 09:00:00",periods=10, freq='30min')
s = pd.Series(range(10),index=rng)
s
# Out:
# 2017-08-22 09:00:00    0
# 2017-08-22 09:30:00    1
# 2017-08-22 10:00:00    2
# 2017-08-22 10:30:00    3
# 2017-08-22 11:00:00    4
# 2017-08-22 11:30:00    5
# 2017-08-22 12:00:00    6
# 2017-08-22 12:30:00    7
# 2017-08-22 13:00:00    8
# 2017-08-22 13:30:00    9
# Freq: 30T, dtype: int64

# %%
b = s.tz_localize(tz="Europe/Berlin")
b
# Out:
# 2017-08-22 09:00:00+02:00    0
# 2017-08-22 09:30:00+02:00    1
# 2017-08-22 10:00:00+02:00    2
# 2017-08-22 10:30:00+02:00    3
# 2017-08-22 11:00:00+02:00    4
# 2017-08-22 11:30:00+02:00    5
# 2017-08-22 12:00:00+02:00    6
# 2017-08-22 12:30:00+02:00    7
# 2017-08-22 13:00:00+02:00    8
# 2017-08-22 13:30:00+02:00    9
# dtype: int64

# %%
b.index
# Out:
# DatetimeIndex(['2017-08-22 09:00:00+02:00', '2017-08-22 09:30:00+02:00',
#                '2017-08-22 10:00:00+02:00', '2017-08-22 10:30:00+02:00',
#                '2017-08-22 11:00:00+02:00', '2017-08-22 11:30:00+02:00',
#                '2017-08-22 12:00:00+02:00', '2017-08-22 12:30:00+02:00',
#                '2017-08-22 13:00:00+02:00', '2017-08-22 13:30:00+02:00'],
#               dtype='datetime64[ns, Europe/Berlin]', freq=None)

# %%
m = s.tz_localize(tz="Asia/Calcutta")
m.index
# Out:
# DatetimeIndex(['2017-08-22 09:00:00+05:30', '2017-08-22 09:30:00+05:30',
#                '2017-08-22 10:00:00+05:30', '2017-08-22 10:30:00+05:30',
#                '2017-08-22 11:00:00+05:30', '2017-08-22 11:30:00+05:30',
#                '2017-08-22 12:00:00+05:30', '2017-08-22 12:30:00+05:30',
#                '2017-08-22 13:00:00+05:30', '2017-08-22 13:30:00+05:30'],
#               dtype='datetime64[ns, Asia/Calcutta]', freq=None)

# %%
m
# Out:
# 2017-08-22 09:00:00+05:30    0
# 2017-08-22 09:30:00+05:30    1
# 2017-08-22 10:00:00+05:30    2
# 2017-08-22 10:30:00+05:30    3
# 2017-08-22 11:00:00+05:30    4
# 2017-08-22 11:30:00+05:30    5
# 2017-08-22 12:00:00+05:30    6
# 2017-08-22 12:30:00+05:30    7
# 2017-08-22 13:00:00+05:30    8
# 2017-08-22 13:30:00+05:30    9
# dtype: int64

# %% [markdown]
# **It will first convert individual timezones to UTC and then align datetimes to perform addition/subtraction etc. operations**

# %%
b + m
# Out:
# 2017-08-22 03:30:00+00:00     NaN
# 2017-08-22 04:00:00+00:00     NaN
# 2017-08-22 04:30:00+00:00     NaN
# 2017-08-22 05:00:00+00:00     NaN
# 2017-08-22 05:30:00+00:00     NaN
# 2017-08-22 06:00:00+00:00     NaN
# 2017-08-22 06:30:00+00:00     NaN
# 2017-08-22 07:00:00+00:00     7.0
# 2017-08-22 07:30:00+00:00     9.0
# 2017-08-22 08:00:00+00:00    11.0
# 2017-08-22 08:30:00+00:00     NaN
# 2017-08-22 09:00:00+00:00     NaN
# 2017-08-22 09:30:00+00:00     NaN
# 2017-08-22 10:00:00+00:00     NaN
# 2017-08-22 10:30:00+00:00     NaN
# 2017-08-22 11:00:00+00:00     NaN
# 2017-08-22 11:30:00+00:00     NaN
# dtype: float64

# %% [markdown]
# **Date alignment is shown below**

# %% [markdown]
# <img src="alignment.png" />

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\20b.csv",parse_dates=['Date'],index_col='Date')
df
# Out:
#              Price
# Date
# 2017-08-15  171.00
# 2017-08-16  170.00
# 2017-08-17  166.91
# 2017-08-18  167.41
# 2017-08-21  167.78
# 2017-08-22  169.64
# 2017-08-23  168.71
# 2017-08-24  167.74
# 2017-08-25  166.32
# 2017-08-28  167.24

# %% [markdown]
# <img src="shift_image.png" />

# %% [markdown]
# <h2 style="color:purple">Shift</h2>

# %%
df.shift(1)
# Out:
#              Price
# Date
# 2017-08-15     NaN
# 2017-08-16  171.00
# 2017-08-17  170.00
# 2017-08-18  166.91
# 2017-08-21  167.41
# 2017-08-22  167.78
# 2017-08-23  169.64
# 2017-08-24  168.71
# 2017-08-25  167.74
# 2017-08-28  166.32

# %%
df.shift(-1)
# Out:
#              Price
# Date
# 2017-08-15  170.00
# 2017-08-16  166.91
# 2017-08-17  167.41
# 2017-08-18  167.78
# 2017-08-21  169.64
# 2017-08-22  168.71
# 2017-08-23  167.74
# 2017-08-24  166.32
# 2017-08-25  167.24
# 2017-08-28     NaN

# %%
df['Prev Day Price'] = df['Price'].shift(1)
df
# Out:
#              Price  Prev Day Price
# Date
# 2017-08-15  171.00             NaN
# 2017-08-16  170.00          171.00
# 2017-08-17  166.91          170.00
# 2017-08-18  167.41          166.91
# 2017-08-21  167.78          167.41
# 2017-08-22  169.64          167.78
# 2017-08-23  168.71          169.64
# 2017-08-24  167.74          168.71
# 2017-08-25  166.32          167.74
# 2017-08-28  167.24          166.32

# %%
df['Price Change'] = df['Price'] - df['Prev Day Price']
df
# Out:
#              Price  Prev Day Price  Price Change
# Date
# 2017-08-15  171.00             NaN           NaN
# 2017-08-16  170.00          171.00         -1.00
# 2017-08-17  166.91          170.00         -3.09
# 2017-08-18  167.41          166.91          0.50
# 2017-08-21  167.78          167.41          0.37
# 2017-08-22  169.64          167.78          1.86
# 2017-08-23  168.71          169.64         -0.93
# 2017-08-24  167.74          168.71         -0.97
# 2017-08-25  166.32          167.74         -1.42
# 2017-08-28  167.24          166.32          0.92

# %%
df['5 day return'] =  (df['Price'] - df['Price'].shift(5))*100/df['Price'].shift(5)
df
# Out:
#              Price  Prev Day Price  Price Change  5 day return
# Date
# 2017-08-15  171.00             NaN           NaN           NaN
# 2017-08-16  170.00          171.00         -1.00           NaN
# 2017-08-17  166.91          170.00         -3.09           NaN
# 2017-08-18  167.41          166.91          0.50           NaN
# 2017-08-21  167.78          167.41          0.37           NaN
# 2017-08-22  169.64          167.78          1.86     -0.795322
# 2017-08-23  168.71          169.64         -0.93     -0.758824
# 2017-08-24  167.74          168.71         -0.97      0.497274
# 2017-08-25  166.32          167.74         -1.42     -0.651096
# 2017-08-28  167.24          166.32          0.92     -0.321850

# %%
df = df[['Price']]
df
# Out:
#              Price
# Date
# 2017-08-15  171.00
# 2017-08-16  170.00
# 2017-08-17  166.91
# 2017-08-18  167.41
# 2017-08-21  167.78
# 2017-08-22  169.64
# 2017-08-23  168.71
# 2017-08-24  167.74
# 2017-08-25  166.32
# 2017-08-28  167.24

# %% [markdown]
# <h2 style="color:purple">tshift</h2>

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#                '2017-08-21', '2017-08-22', '2017-08-23', '2017-08-24',
#                '2017-08-25', '2017-08-28'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df.index = pd.date_range(start='2017-08-15',periods=10, freq='B')
df
# Out:
#              Price
# 2017-08-15  171.00
# 2017-08-16  170.00
# 2017-08-17  166.91
# 2017-08-18  167.41
# 2017-08-21  167.78
# 2017-08-22  169.64
# 2017-08-23  168.71
# 2017-08-24  167.74
# 2017-08-25  166.32
# 2017-08-28  167.24

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#                '2017-08-21', '2017-08-22', '2017-08-23', '2017-08-24',
#                '2017-08-25', '2017-08-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.tshift(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9468/4060579993.py:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   df.tshift(1)
#              Price
# 2017-08-16  171.00
# 2017-08-17  170.00
# 2017-08-18  166.91
# 2017-08-21  167.41
# 2017-08-22  167.78
# 2017-08-23  169.64
# 2017-08-24  168.71
# 2017-08-25  167.74
# 2017-08-28  166.32
# 2017-08-29  167.24

# %% [markdown]
# # <font color="purple"><h3 align="center">Dataframe and mysql database tutorial</h3></font>

# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/application')

# %% [markdown]
# Format of connection string is:
#
# mysql+pymysql://username:password@host:port/database_name
#
# Format of connection string for other databases
#
# https://pandas.pydata.org/pandas-docs/stable/io.html#engine-connection-examples

# %% [markdown]
# <img src="conn_string_format.JPG"/>

# %% [markdown]
# <h3 style="color:purple">Read entire table in a dataframe using <span style="color:blue">read_sql_table</span></h3>

# %%
df = pd.read_sql_table('customers',engine)
df
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/2596682552.py in <module>
# ----> 1 df = pd.read_sql_table('customers',engine)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     318     meta = MetaData(con, schema=schema)
#     319     try:
# --> 320         meta.reflect(only=[table_name], views=True)
#     321     except sqlalchemy.exc.InvalidRequestError as err:
#     322         raise ValueError(f"Table {table_name} not found") from err
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4650             bind = _bind_or_error(self)
#    4651
# -> 4652         with inspection.inspect(bind)._inspection_context() as insp:
#    4653             reflect_opts = {
#    4654                 "autoload_with": insp,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# **Read only selected columns**

# %%
df = pd.read_sql_table('customers', engine, columns=["name"])
df
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/2845853025.py in <module>
# ----> 1 df = pd.read_sql_table('customers', engine, columns=["name"])
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     318     meta = MetaData(con, schema=schema)
#     319     try:
# --> 320         meta.reflect(only=[table_name], views=True)
#     321     except sqlalchemy.exc.InvalidRequestError as err:
#     322         raise ValueError(f"Table {table_name} not found") from err
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4650             bind = _bind_or_error(self)
#    4651
# -> 4652         with inspection.inspect(bind)._inspection_context() as insp:
#    4653             reflect_opts = {
#    4654                 "autoload_with": insp,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# <h3 style="color:purple">Join two tables and read them in a dataframe using <span style="color:blue">read_sql_query</span></h3>

# %%
df = pd.read_sql_query("select id,name from customers",engine)
df
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/3967636454.py in <module>
# ----> 1 df = pd.read_sql_query("select id,name from customers",engine)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     434     """
#     435     pandas_sql = pandasSQL_builder(con)
# --> 436     return pandas_sql.read_query(
#     437         sql,
#     438         index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1422     def execute(self, *args, **kwargs):
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#    1426     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3105
#    3106         """
# -> 3107         connection = self.connect(close_with_result=True)
#    3108         return connection.execute(statement, *multiparams, **params)
#    3109
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
query = '''
 SELECT customers.name, customers.phone_number, orders.name, orders.amount
 FROM customers INNER JOIN orders
 ON customers.id=orders.customer_id
'''
df = pd.read_sql_query(query,engine)
df

# %% [markdown]
# <h3 style="color:purple"><span style="color:blue">read_sql</span> is a wrapper around read_sql_query and read_sql_table</h3>

# %%
query = '''
 SELECT customers.name, customers.phone_number, orders.name, orders.amount
 FROM customers INNER JOIN orders
 ON customers.id=orders.customer_id
'''
pd.read_sql(query,engine)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/3342580517.py in <module>
#       4  ON customers.id=orders.customer_id
#       5 '''
# ----> 6 pd.read_sql(query,engine)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     626         )
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#     630             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1422     def execute(self, *args, **kwargs):
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#    1426     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3105
#    3106         """
# -> 3107         connection = self.connect(close_with_result=True)
#    3108         return connection.execute(statement, *multiparams, **params)
#    3109
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
pd.read_sql("customers",engine)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/3785645579.py in <module>
# ----> 1 pd.read_sql("customers",engine)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     626         )
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#     630             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1422     def execute(self, *args, **kwargs):
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#    1426     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3105
#    3106         """
# -> 3107         connection = self.connect(close_with_result=True)
#    3108         return connection.execute(statement, *multiparams, **params)
#    3109
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# <h3 style="color:purple">Write to mysql database using <span style="color:blue">to_sql</span></h3>

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\21b.csv")
df
# Out:
#      Customer Name  Customer Phone
# 0     rafael nadal      4567895647
# 1  maria sharapova       434534545
# 2   vladimir putin        89345345
# 3      kim un jong       123434456
# 4       jeff bezos       934534543
# 5     rahul gandhi        44324222

# %%
df.rename(columns={
    'Customer Name': 'name',
    'Customer Phone': 'phone_number'
}, inplace=True)
df
# Out:
#               name  phone_number
# 0     rafael nadal    4567895647
# 1  maria sharapova     434534545
# 2   vladimir putin      89345345
# 3      kim un jong     123434456
# 4       jeff bezos     934534543
# 5     rahul gandhi      44324222

# %%
df.to_sql(
    name='customers', # database table name
    con=engine,
    if_exists='append',
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9468/3770357715.py in <module>
# ----> 1 df.to_sql(
#       2     name='customers', # database table name
#       3     con=engine,
#       4     if_exists='append',
#       5     index=False
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1749         sql_engine = get_engine(engine)
#    1750
# -> 1751         table = self.prep_table(
#    1752             frame=frame,
#    1753             name=name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     854
#     855     def create(self):
# --> 856         if self.exists():
#     857             if self.if_exists == "fail":
#     858                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     838
#     839     def exists(self):
# --> 840         return self.pd_sql.has_table(self.name, self.schema)
#     841
#     842     def sql_schema(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1781             import sqlalchemy as sa
#    1782
# -> 1783             insp = sa.inspect(self.connectable)
#    1784             return insp.has_table(name, schema or self.meta.schema)
#    1785         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# **to_sql has different parameters such as chunksize which allows to write data in chunks. This is useful when
# size of dataframe is huge**

# %%
C:\\Users\\Admin\\OneDrive\\Desktop\\GitHub\\KsRenu\\Practice-Codes\\PANDAS-youtube\\7d.csv
